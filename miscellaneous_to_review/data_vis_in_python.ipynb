# %% [markdown]
# <a href="https://colab.research.google.com/github/wokech/python_tutorials/blob/main/data_vis_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Visualization using Python**

# %% [markdown]
# Data visualizations created using the most popular Python libraries (**matplotlib, seaborn and plotly**)
#
# Adapted from work by Jesús López
#
# https://blog.resolvingpython.com/04-data-visualization-in-python

# %% [markdown]
# ## 3 main libraries for Data Visualization in Python:
#
# * Matplotlib (Mathematical Plotting)
#
# * Seaborn (High-Level based on Matplotlib)
#
# * Plotly (Animated Plots)

# %% [markdown]
# ## 1) Plotly

# %%
import plotly.express as px

df_countries = px.data.gapminder()
df_countries
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %% [markdown]
# ## *2*) Plotly

# %% [markdown]
# Basic Plots

# %%
df_countries_2007 = df_countries.query('year == 2007')

px.scatter(data_frame=df_countries_2007, x='gdpPercap', y='lifeExp',
           color='continent', hover_name='country', size='pop')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Animated Plots

# %%
px.scatter(df_countries, x="gdpPercap", y="lifeExp", animation_frame="year", animation_group="country",
           size="pop", color="continent", hover_name="country",
           log_x=True, size_max=55, range_x=[100,100000], range_y=[25,90])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 3) Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Bar Plot

# %%
plt.bar(x=['Real Madrid', 'Barcelona', 'Bayern Munich'],
       height=[14, 5, 6]);

# %% [markdown]
# Point Plot

# %%
plt.scatter(x=['Real Madrid', 'Barcelona', 'Bayern Munich'],
            y=[14, 5, 6]);

# %% [markdown]
# ## Visualize the DataFrame

# %%
teams = ['Real Madrid', 'Barcelona', 'Bayern Munich']
uefa_champions = [14, 5, 6]

import pandas as pd

df_champions = pd.DataFrame(data={'Team': teams,
                   'UEFA Champions': uefa_champions})
df_champions
# Out:
#             Team  UEFA Champions
# 0    Real Madrid              14
# 1      Barcelona               5
# 2  Bayern Munich               6

# %%
plt.bar(x=df_champions['Team'],
        height=df_champions['UEFA Champions']);

# %% [markdown]
# ## DataFrame functions

# %%
df_champions.plot.bar(x='Team', y='UEFA Champions');

# %% [markdown]
# ## *3*) Seaborn

# %%
df_premier = pd.read_excel(io='premier_league.xlsx')
df_premier
# Out:
#                        Team  Pl   W   D   L   F   A  GD  Pts
# 0           Manchester City  38  29   6   3  99  26  73   93
# 1                 Liverpool  38  28   8   2  94  26  68   92
# 2                   Chelsea  38  21  11   6  76  33  43   74
# 3         Tottenham Hotspur  38  22   5  11  69  40  29   71
# 4                   Arsenal  38  22   3  13  61  48  13   69
# 5         Manchester United  38  16  10  12  57  57   0   58
# 6           West Ham United  38  16   8  14  60  51   9   56
# 7            Leicester City  38  14  10  14  62  59   3   52
# 8    Brighton & Hove Albion  38  12  15  11  42  44  -2   51
# 9   Wolverhampton Wanderers  38  15   6  17  38  43  -5   51
# 10         Newcastle United  38  13  10  15  44  62 -18   49
# 11           Crystal Palace  38  11  15  12  50  46   4   48
# 12                Brentford  38  13   7  18  48  56  -8   46
# 13              Aston Villa  38  13   6  19  52  54  -2   45
# ...

# %% [markdown]
# Scatter plot (seaborn)

# %%
import seaborn as sns

sns.scatterplot(x='F', y='Pts', data=df_premier);

# %% [markdown]
# Scatter plot (matplotlib)

# %%
plt.scatter(x='F', y='Pts', data=df_premier);

# %% [markdown]
# Differences:
# * matplotlib points are bigger than seaborn ones
# * matplotlib axis labels are non-existent, whereas seaborn places the names of the columns

# %%
seaborn_plot = sns.scatterplot(x='F', y='Pts', data=df_premier);

matplotlib_plot = plt.scatter(x='F', y='Pts', data=df_premier);

# %%
type(seaborn_plot)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
type(matplotlib_plot)
# Out:
# matplotlib.collections.PathCollection

# %% [markdown]
# Place the names of the teams in the points

# %%
plt.scatter(x='F', y='Pts', data=df_premier)

for idx, data in df_premier.iterrows():
    plt.text(x=data['F'], y=data['Pts'], s=data['Team'])

# %% [markdown]
# An easier way - use plotly library
#
# express module within plotly library to access the functions of the plots

# %%
import plotly.express as px

px.scatter(data_frame=df_premier, x='W', y='Pts', hover_name='Team')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Types of Plots

# %% [markdown]
# Another dataset: the sociological data of clients in a restaurant.

# %%
df_tips = sns.load_dataset(name='tips')
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## One Column

# %% [markdown]
# Categorical Column

# %%
df_tips.sex
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: sex, Length: 244, dtype: category
# Categories (2, object): ['Male', 'Female']

# %% [markdown]
# Summarise the data first; we count how many Female and Male people are in the dataset.

# %%
df_tips.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
sr_sex = df_tips.sex.value_counts()

# %% [markdown]
# Barplot

# %%
px.bar(x=sr_sex.index, y=sr_sex.values)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# We can also colour the bars based on the category:

# %%
px.bar(x=sr_sex.index, y=sr_sex.values, color=sr_sex.index)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Pie plot

# %%
px.pie(names=sr_sex.index, values=sr_sex.values, color=sr_sex.index)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Numerical Column

# %%
df_tips.total_bill
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %% [markdown]
# Histogram

# %%
px.histogram(x=df_tips.total_bill)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Boxplot

# %%
px.box(x=df_tips.total_bill)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Two Columns

# %%
df_tips[['total_bill', 'tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %% [markdown]
# ## Numerical & Numerical
#
# We use a scatter plot to see if a relationship exists between two numerical variables.

# %%
px.scatter(x='total_bill', y='tip', data_frame=df_tips)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Another type of visualization for 2 continuous variables:

# %%
px.density_contour(x='total_bill', y='tip', data_frame=df_tips)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Numerical & Categorical

# %%
df_tips[['day', 'total_bill']]
# Out:
#       day  total_bill
# 0     Sun       16.99
# 1     Sun       10.34
# 2     Sun       21.01
# 3     Sun       23.68
# 4     Sun       24.59
# ..    ...         ...
# 239   Sat       29.03
# 240   Sat       27.18
# 241   Sat       22.67
# 242   Sat       17.82
# 243  Thur       18.78
#
# [244 rows x 2 columns]

# %% [markdown]
# We can summarise the data around how much revenue was generated in each day of the week.

# %%
df_tips.groupby('day').total_bill.sum()
# Out:
# day
# Thur    1096.33
# Fri      325.88
# Sat     1778.40
# Sun     1627.16
# Name: total_bill, dtype: float64

# %%
sr_days = df_tips.groupby('day').total_bill.sum()

# %% [markdown]
# Barplot

# %%
px.bar(x=sr_days.index, y=sr_days.values)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(x=sr_days.index, y=sr_days.values, color=sr_days.index)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Categorical & Categorical

# %%
df_tips[['day', 'size']]
# Out:
#       day  size
# 0     Sun     2
# 1     Sun     3
# 2     Sun     3
# 3     Sun     2
# 4     Sun     4
# ..    ...   ...
# 239   Sat     3
# 240   Sat     2
# 241   Sat     2
# 242   Sat     2
# 243  Thur     2
#
# [244 rows x 2 columns]

# %%
px.density_heatmap(x='day', y='size', data_frame=df_tips)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Awesome Plots (Maps)

# %%
df_gapminder = px.data.gapminder()
px.scatter_geo(df_gapminder, locations="iso_alpha", color="continent", #!
                     hover_name="country", size="pop",
                     animation_frame="year",
                     projection="natural earth")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

df = px.data.election()
geojson = px.data.election_geojson()

fig = px.choropleth_mapbox(df, geojson=geojson, color="Bergeron",
                           locations="district", featureidkey="properties.district",
                           center={"lat": 45.5517, "lon": -73.7073},
                           mapbox_style="carto-positron", zoom=9)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df
# Out:
#                                              district  Coderre  Bergeron  \
# 0                                  101-Bois-de-Liesse     2481      1829
# 1                               102-Cap-Saint-Jacques     2525      1163
# 2                                11-Sault-au-Récollet     3348      2770
# 3                                        111-Mile-End     1734      4782
# 4                                      112-DeLorimier     1770      5933
# 5                                    113-Jeanne-Mance     1455      3599
# 6                                    12-Saint-Sulpice     3252      2521
# 7                          121-La Pointe-aux-Prairies     5456      1760
# 8                             122-Pointe-aux-Trembles     4734      1879
# 9                            123-Rivière-des-Prairies     5737       958
# 10                                        13-Ahuntsic     2979      3430
# 11                                  131-Saint-Édouard     1827      6408
# ...

# %%
import plotly.express as px

df = px.data.election()
geojson = px.data.election_geojson()

fig = px.choropleth_mapbox(df, geojson=geojson, color="winner",
                           locations="district", featureidkey="properties.district",
                           center={"lat": 45.5517, "lon": -73.7073},
                           mapbox_style="carto-positron", zoom=9)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
